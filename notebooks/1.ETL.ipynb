# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)

# %%
data_directory = r'C:\Users\Isaac\Documents\Proyecto_Individual_2'
os.chdir(data_directory)

# %% [markdown]
# # ETL dataframe `LESIONES HECHOS`

# %%
# Carga del archivo
lesiones = pd.read_excel('datasets/raw/lesiones.xlsx', sheet_name='HECHOS', na_values=['SD', 'sd'])
lesiones
# Out:
#                     id  n_victimas  aaaa  mm  dd                fecha  \
# 0      LC-2019-0000179           1  2019   1   1  2019-01-01 00:00:00
# 1      LC-2019-0000053           1  2019   1   1  2019-01-01 00:00:00
# 2      LC-2019-0000063           1  2019   1   1  2019-01-01 00:00:00
# 3      LC-2019-0000079           1  2019   1   1  2019-01-01 00:00:00
# 4      LC-2019-0000082           4  2019   1   1  2019-01-01 00:00:00
# ...                ...         ...   ...  ..  ..                  ...
# 23780  LC-2021-0652849           1  2021  12  31  2021-12-31 00:00:00
# 23781  LC-2021-0652865           2  2021  12  31  2021-12-31 00:00:00
# 23782  LC-2021-0652907           1  2021  12  31  2021-12-31 00:00:00
# 23783  LC-2021-0652921           1  2021  12  31  2021-12-31 00:00:00
# 23784  LC-2020-0244615           1  2020   5  17            5/17/2020
#
#            hora  franja_hora                 direccion_normalizada comuna  \
# 0      09:00:00          9.0                                   NaN     14
# 1      01:55:00          1.0                                   NaN      8
# 2      02:00:00          2.0                                   NaN      8
# 3      02:30:00          2.0                                   NaN      7
# 4      04:30:00          4.0                                   NaN      3
# ...         ...          ...                                   ...    ...
# 23780  19:30:00         19.0  ALBERDI, JUAN BAUTISTA AV. y GUAMINI      9
# 23781  19:40:00         19.0       ALBERDI, JUAN BAUTISTA AV. 4436      9
# 23782  20:00:00         20.0                                   NaN      1
# 23783  22:00:00         22.0               LINIERS VIRREY y MORENO      5
# 23784  21:00:00         21.0                                   NaN    NaN
#
#       tipo_calle                                     otra_direccion  \
# 0            NaN  Obligado Rafael, Av.Costanera 3300, Barrio: Pa...
# 1            NaN  Autopista Presidente Héctor J. Cámpora y Roca,...
# 2            NaN  Barros Pazos, Jose y Larraya 0, Barrio: Villa ...
# 3            NaN  Torres Y Tenorio, Pres. y Riestra Av. 0, Barri...
# 4            NaN  Corrientes Av. y Uriburu Jose E., Pres. 0, Bar...
# ...          ...                                                ...
# 23780    AVENIDA                                                NaN
# 23781    AVENIDA                                                NaN
# 23782        NaN          Barrio Padre Carlos Mugica (Villa 31 bis)
# 23783      CALLE                                                NaN
# 23784        NaN                                                NaN
#
#                             calle  altura    cruce  \
# 0                             NaN     NaN      NaN
# 1                             NaN     NaN      NaN
# 2                             NaN     NaN      NaN
# 3                             NaN     NaN      NaN
# 4                             NaN     NaN      NaN
# ...                           ...     ...      ...
# 23780  ALBERDI, JUAN BAUTISTA AV.     0.0  GUAMINI
# 23781  ALBERDI, JUAN BAUTISTA AV.  4436.0      NaN
# 23782                         NaN     NaN      NaN
# 23783              LINIERS VIRREY     0.0   MORENO
# 23784                         NaN     0.0      NaN
#
#                                     geocodificacion_CABA      longitud  \
# 0      Point (104991.46333918849995825 107720.9664748... -5.840891e+01
# 1      Point (101813.84712503915943671 95578.55507230... -5.844351e+01
# 2      Point (99538.58660300650808495 94643.418717990... -5.846834e+01
# 3      Point (102372.16830963784013875 97994.13750300... -5.843742e+01
# 4      Point (105968.98286849579017144 102737.1734686... -5.839822e+01
# ...                                                  ...           ...
# 23780          Point (95400.5441905024 96621.6007711877) -5.851348e+01
# 23781          Point (97705.4491469278 98614.8825470092) -5.848833e+01
# 23782  Point (107377.10694920316745993 105120.7873965... -5.838289e+01
# 23783          Point (104472.702045632 101660.930364258) -5.841453e+01
# 23784  Point (114990.04979284359433223 88934.67755418... -5.829963e+09
#
#             latutid   victima             acusado            participantes  \
# 0     -3.455966e+01  CICLISTA                 NaN              CICLISTA-SD
# 1     -3.466913e+01      AUTO                 NaN                  AUTO-SD
# 2     -3.467756e+01       NaN                 NaN                    SD-SD
# 3     -3.464735e+01    PEATON                 NaN                PEATON-SD
# 4     -3.460458e+01      AUTO                 NaN                  AUTO-SD
# ...             ...       ...                 ...                      ...
# 23780 -3.465971e+01       NaN                 NaN                    SD-SD
# 23781 -3.464175e+01       NaN                 NaN                    SD-SD
# 23782 -3.458308e+01       NaN                 NaN                    SD-SD
# 23783 -3.461429e+01      MOTO  TRANSPORTE PUBLICO  MOTO-TRANSPORTE PUBLICO
# 23784 -3.472891e+09      MOTO                AUTO                MOTO-AUTO
#
#       moto auto transporte_publico camion ciclista gravedad
# 0      NaN  NaN                NaN    NaN        x      NaN
# 1      NaN    x                NaN    NaN      NaN      NaN
# 2      NaN  NaN                NaN    NaN      NaN      NaN
# 3        x  NaN                NaN    NaN      NaN      NaN
# 4      NaN  NaN                  x    NaN      NaN      NaN
# ...    ...  ...                ...    ...      ...      ...
# 23780  NaN  NaN                NaN    NaN      NaN      NaN
# 23781  NaN  NaN                NaN    NaN      NaN      NaN
# 23782  NaN  NaN                NaN    NaN      NaN      NaN
# 23783    x    0                  x      0        0    GRAVE
# 23784    x    x                  0      0        0      NaN
#
# [23785 rows x 27 columns]

# %% [markdown]
# Función que permetirá ir corroborando la integridad de nuestros datos

# %%
def resumen_tipos_de_datos(df):
    resumen = []
    total_filas = len(df)
    for col in df.columns:
        tipos_presentes = df[col].apply(lambda x: type(x).__name__).unique()
        cantidad_nulos = df[col].isnull().sum()
        porcentaje_nulos = round((cantidad_nulos / total_filas) * 100, 2)

        resumen.append({
            'Columna': col,
            'Tipos de Dato': tipos_presentes.tolist(),
            'Cantidad de Nulos': cantidad_nulos,
            '% de Nulos': porcentaje_nulos
        })
    return pd.DataFrame(resumen)

# %%
resumen_tipos_de_datos(lesiones)
# Out:
#                   Columna       Tipos de Dato  Cantidad de Nulos  % de Nulos
# 0                      id               [str]                  0        0.00
# 1              n_victimas               [int]                  0        0.00
# 2                    aaaa               [int]                  0        0.00
# 3                      mm               [int]                  0        0.00
# 4                      dd               [int]                  0        0.00
# 5                   fecha     [datetime, str]                  0        0.00
# 6                    hora  [time, float, str]                  9        0.04
# 7             franja_hora             [float]                  9        0.04
# 8   direccion_normalizada        [float, str]              10868       45.69
# 9                  comuna   [int, str, float]               1015        4.27
# 10             tipo_calle        [float, str]              11045       46.44
# 11         otra_direccion        [str, float]              18295       76.92
# 12                  calle        [float, str]              10918       45.90
# 13                 altura             [float]              11014       46.31
# 14                  cruce        [float, str]              14378       60.45
# 15   geocodificacion_CABA        [str, float]               1252        5.26
# 16               longitud             [float]               1471        6.18
# 17                latutid             [float]               1471        6.18
# 18                victima        [str, float]              10733       45.13
# 19                acusado        [float, str]              15288       64.28
# 20          participantes               [str]                  0        0.00
# 21                   moto   [float, str, int]               8604       36.17
# 22                   auto   [float, str, int]              12636       53.13
# 23     transporte_publico   [float, str, int]              11894       50.01
# 24                 camion   [float, str, int]              12801       53.82
# 25               ciclista   [str, float, int]              11446       48.12
# 26               gravedad        [float, str]              23139       97.28

# %% [markdown]
# ### 1. Eliminación de columnas

# %% [markdown]
# La columna 'fecha' se conservará, las columnas `aaaa`, `mm`, y `dd`, serán eliminados por ser considerados datos redundates.

# %%
lesiones.drop(columns=['aaaa','mm','dd'], inplace=True)

# %% [markdown]
# Eliminamos columna `hora`, para conservar la columna `franja_hora`, porque tiene la hora en entero, esto optimiza futuros análisis.

# %%
lesiones.drop(columns=['hora'],inplace=True)

# %% [markdown]
# Para la ubicación se utilizará las columnas `latitud` y `longitud`. Procederemos a eliminar las columnas relacionadas a direcciones.

# %%
lesiones.drop(columns=['otra_direccion','calle','altura','cruce','geocodificacion_CABA','direccion_normalizada'],inplace=True)

# %% [markdown]
# La columna `participantes`detalla la información sobre los involucrados en el incidente, por tanto, columnas para detallar la presencia de **moto**, **auto**, **transporte público**, **camión** y **ciclista** resultan redundantes.

# %%
lesiones.drop(columns=['moto','auto','transporte_publico','camion','ciclista'],inplace=True)

# %%
# Corroboramos la integridad de nuestro DF
resumen_tipos_de_datos(lesiones)
# Out:
#           Columna      Tipos de Dato  Cantidad de Nulos  % de Nulos
# 0              id              [str]                  0        0.00
# 1      n_victimas              [int]                  0        0.00
# 2           fecha    [datetime, str]                  0        0.00
# 3     franja_hora            [float]                  9        0.04
# 4          comuna  [int, str, float]               1015        4.27
# 5      tipo_calle       [float, str]              11045       46.44
# 6        longitud            [float]               1471        6.18
# 7         latutid            [float]               1471        6.18
# 8         victima       [str, float]              10733       45.13
# 9         acusado       [float, str]              15288       64.28
# 10  participantes              [str]                  0        0.00
# 11       gravedad       [float, str]              23139       97.28

# %% [markdown]
# La columna `gravedad` muestra una cantidad alarmante de valores nulos. No obstante, al revisar el diccionario, se aclara que se debe considerar como gravedad `leve`.

# %%
lesiones['gravedad'] = lesiones['gravedad'].fillna('leve')

# %%
# Verificamos como va quedando el DF
df_lesiones_hechos = lesiones
df_lesiones_hechos
# Out:
#                     id  n_victimas                fecha  franja_hora comuna  \
# 0      LC-2019-0000179           1  2019-01-01 00:00:00          9.0     14
# 1      LC-2019-0000053           1  2019-01-01 00:00:00          1.0      8
# 2      LC-2019-0000063           1  2019-01-01 00:00:00          2.0      8
# 3      LC-2019-0000079           1  2019-01-01 00:00:00          2.0      7
# 4      LC-2019-0000082           4  2019-01-01 00:00:00          4.0      3
# ...                ...         ...                  ...          ...    ...
# 23780  LC-2021-0652849           1  2021-12-31 00:00:00         19.0      9
# 23781  LC-2021-0652865           2  2021-12-31 00:00:00         19.0      9
# 23782  LC-2021-0652907           1  2021-12-31 00:00:00         20.0      1
# 23783  LC-2021-0652921           1  2021-12-31 00:00:00         22.0      5
# 23784  LC-2020-0244615           1            5/17/2020         21.0    NaN
#
#       tipo_calle      longitud       latutid   victima             acusado  \
# 0            NaN -5.840891e+01 -3.455966e+01  CICLISTA                 NaN
# 1            NaN -5.844351e+01 -3.466913e+01      AUTO                 NaN
# 2            NaN -5.846834e+01 -3.467756e+01       NaN                 NaN
# 3            NaN -5.843742e+01 -3.464735e+01    PEATON                 NaN
# 4            NaN -5.839822e+01 -3.460458e+01      AUTO                 NaN
# ...          ...           ...           ...       ...                 ...
# 23780    AVENIDA -5.851348e+01 -3.465971e+01       NaN                 NaN
# 23781    AVENIDA -5.848833e+01 -3.464175e+01       NaN                 NaN
# 23782        NaN -5.838289e+01 -3.458308e+01       NaN                 NaN
# 23783      CALLE -5.841453e+01 -3.461429e+01      MOTO  TRANSPORTE PUBLICO
# 23784        NaN -5.829963e+09 -3.472891e+09      MOTO                AUTO
#
#                  participantes gravedad
# 0                  CICLISTA-SD     leve
# 1                      AUTO-SD     leve
# 2                        SD-SD     leve
# 3                    PEATON-SD     leve
# 4                      AUTO-SD     leve
# ...                        ...      ...
# 23780                    SD-SD     leve
# 23781                    SD-SD     leve
# 23782                    SD-SD     leve
# 23783  MOTO-TRANSPORTE PUBLICO    GRAVE
# 23784                MOTO-AUTO     leve
#
# [23785 rows x 12 columns]

# %% [markdown]
# En la columna `comuna`, los datos 'No Especificada' serán convertidos a nulos.

# %%
df_lesiones_hechos['comuna'] = df_lesiones_hechos['comuna'].replace('No Especificada', np.NaN)

# %% [markdown]
# ### 2. Cambio de tipos de datos
# Las columnas `franja_hora`, `tipo_calle`, `comuna` y ``acusado`` serán transformadas a tipo categórico.

# %%
# Normalizamos todos los valores nulos
mask = df_lesiones_hechos.applymap(lambda x: x == '<NA>')
df_lesiones_hechos[mask] = np.NaN

# %%
df_lesiones_hechos['tipo_calle'] = df_lesiones_hechos['tipo_calle'].astype('category')
df_lesiones_hechos['acusado'] = df_lesiones_hechos['acusado'].astype('category')

# %% [markdown]
# La columna ``fecha`` la convertiremos a formato fecha

# %%
df_lesiones_hechos['fecha'] = pd.to_datetime(df_lesiones_hechos['fecha'], errors='coerce')

# %% [markdown]
# La columna ``comuna`` y ``franja_hora`` la convertiremos a formato INT

# %%
df_lesiones_hechos['comuna'] = df_lesiones_hechos['comuna'].astype('Int64')
df_lesiones_hechos['franja_hora'] = df_lesiones_hechos['franja_hora'].astype('Int64')

# %%
df_lesiones_hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23785 entries, 0 to 23784
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             23785 non-null  object
#  1   n_victimas     23785 non-null  int64
#  2   fecha          23785 non-null  datetime64[ns]
#  3   franja_hora    23776 non-null  Int64
#  4   comuna         22328 non-null  Int64
#  5   tipo_calle     12740 non-null  category
#  6   longitud       22314 non-null  float64
#  7   latutid        22314 non-null  float64
#  8   victima        13052 non-null  object
#  9   acusado        8497 non-null   category
#  10  participantes  23785 non-null  object
#  11  gravedad       23785 non-null  object
# dtypes: Int64(2), category(2), datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# ### 3. Renombrar columnas

# %%
df_lesiones_hechos.head()
# Out:
#                 id  n_victimas      fecha  franja_hora  comuna tipo_calle  \
# 0  LC-2019-0000179           1 2019-01-01            9      14        NaN
# 1  LC-2019-0000053           1 2019-01-01            1       8        NaN
# 2  LC-2019-0000063           1 2019-01-01            2       8        NaN
# 3  LC-2019-0000079           1 2019-01-01            2       7        NaN
# 4  LC-2019-0000082           4 2019-01-01            4       3        NaN
#
#     longitud    latutid   victima acusado participantes gravedad
# 0 -58.408911 -34.559658  CICLISTA     NaN   CICLISTA-SD     leve
# 1 -58.443510 -34.669125      AUTO     NaN       AUTO-SD     leve
# 2 -58.468335 -34.677556       NaN     NaN         SD-SD     leve
# 3 -58.437425 -34.647349    PEATON     NaN     PEATON-SD     leve
# 4 -58.398225 -34.604579      AUTO     NaN       AUTO-SD     leve

# %% [markdown]
# Cambiamos todos los nombres de las columnas, para poder darle un mejor seguimiento

# %%
df_lesiones_hechos = df_lesiones_hechos.rename(columns={'id':'id_hecho'})
df_lesiones_hechos = df_lesiones_hechos.rename(columns={'franja_hora':'hh'})
df_lesiones_hechos = df_lesiones_hechos.rename(columns={'latutid':'latitud'})

# %%
df_lesiones_hechos.head()
# Out:
#           id_hecho  n_victimas      fecha  hh  comuna tipo_calle   longitud  \
# 0  LC-2019-0000179           1 2019-01-01   9      14        NaN -58.408911
# 1  LC-2019-0000053           1 2019-01-01   1       8        NaN -58.443510
# 2  LC-2019-0000063           1 2019-01-01   2       8        NaN -58.468335
# 3  LC-2019-0000079           1 2019-01-01   2       7        NaN -58.437425
# 4  LC-2019-0000082           4 2019-01-01   4       3        NaN -58.398225
#
#      latitud   victima acusado participantes gravedad
# 0 -34.559658  CICLISTA     NaN   CICLISTA-SD     leve
# 1 -34.669125      AUTO     NaN       AUTO-SD     leve
# 2 -34.677556       NaN     NaN         SD-SD     leve
# 3 -34.647349    PEATON     NaN     PEATON-SD     leve
# 4 -34.604579      AUTO     NaN       AUTO-SD     leve

# %%
# Transformar a minúsculas las columnas en df_lesiones_hechos
columnas_a_minusc = ['tipo_calle', 'gravedad', 'victima', 'acusado', 'participantes']
df_lesiones_hechos[columnas_a_minusc] = df_lesiones_hechos[columnas_a_minusc].apply(lambda x: x.astype(str).str.lower())

# Correciones ortográficas
mapeo_correcciones_victima_lesiones = {'peaton': 'peatón','transporte publico': 'transporte público','movil': 'móvil','otro': 'otro',
'camion': 'camión','monopatin': 'monopatín','utilitario': 'utilitario'}
df_lesiones_hechos['victima'] = df_lesiones_hechos['victima'].replace(mapeo_correcciones_victima_lesiones)

# %%
df_lesiones_hechos.head()
# Out:
#           id_hecho  n_victimas      fecha  hh  comuna tipo_calle   longitud  \
# 0  LC-2019-0000179           1 2019-01-01   9      14        nan -58.408911
# 1  LC-2019-0000053           1 2019-01-01   1       8        nan -58.443510
# 2  LC-2019-0000063           1 2019-01-01   2       8        nan -58.468335
# 3  LC-2019-0000079           1 2019-01-01   2       7        nan -58.437425
# 4  LC-2019-0000082           4 2019-01-01   4       3        nan -58.398225
#
#      latitud   victima acusado participantes gravedad
# 0 -34.559658  ciclista     nan   ciclista-sd     leve
# 1 -34.669125      auto     nan       auto-sd     leve
# 2 -34.677556       nan     nan         sd-sd     leve
# 3 -34.647349    peatón     nan     peaton-sd     leve
# 4 -34.604579      auto     nan       auto-sd     leve

# %%
df_lesiones_hechos.replace('nan', np.nan, inplace=True)

# %%
df_lesiones_hechos.head()
# Out:
#           id_hecho  n_victimas      fecha  hh  comuna tipo_calle   longitud  \
# 0  LC-2019-0000179           1 2019-01-01   9      14        NaN -58.408911
# 1  LC-2019-0000053           1 2019-01-01   1       8        NaN -58.443510
# 2  LC-2019-0000063           1 2019-01-01   2       8        NaN -58.468335
# 3  LC-2019-0000079           1 2019-01-01   2       7        NaN -58.437425
# 4  LC-2019-0000082           4 2019-01-01   4       3        NaN -58.398225
#
#      latitud   victima acusado participantes gravedad
# 0 -34.559658  ciclista     NaN   ciclista-sd     leve
# 1 -34.669125      auto     NaN       auto-sd     leve
# 2 -34.677556       NaN     NaN         sd-sd     leve
# 3 -34.647349    peatón     NaN     peaton-sd     leve
# 4 -34.604579      auto     NaN       auto-sd     leve

# %% [markdown]
# # ETL dataframe ``LESIONES-VICTIMAS``

# %%
# Carga del archivo
df_lesiones_victimas = pd.read_excel('datasets/raw/lesiones.xlsx', sheet_name='VICTIMAS', na_values=['SD', 'sd'])
df_lesiones_victimas
# Out:
#               ID hecho   AAA  MM  DD     FECHA     VEHICULO_VICTIMA   SEXO  \
# 0      LC-2019-0000053  2019   1   1 2019-01-01                 NaN  Varon
# 1      LC-2019-0000063  2019   1   1 2019-01-01                 NaN    NaN
# 2      LC-2019-0000079  2019   1   1 2019-01-01                 NaN  Varon
# 3      LC-2019-0000082  2019   1   1 2019-01-01                 NaN  Varon
# 4      LC-2019-0000082  2019   1   1 2019-01-01                 NaN  Mujer
# ...                ...   ...  ..  ..        ...                 ...    ...
# 27600  LC-2021-0451911  2021   9  11 2021-09-11  TRANSPORTE PUBLICO  Varon
# 27601  LC-2021-0530228  2021  10  25 2021-10-25  TRANSPORTE PUBLICO  Mujer
# 27602  LC-2021-0530228  2021  10  25 2021-10-25  TRANSPORTE PUBLICO  Mujer
# 27603  LC-2021-0201378  2021   5   2 2021-05-02                MOTO  Varon
# 27604  LC-2021-0229350  2021   5  19 2021-05-19                MOTO  Varon
#
#        EDAD_VICTIMA GRAVEDAD
# 0              57.0      NaN
# 1               NaN      NaN
# 2               NaN      NaN
# 3              45.0      NaN
# 4              45.0      NaN
# ...             ...      ...
# 27600          87.0      NaN
# 27601          60.0      NaN
# 27602          32.0      NaN
# 27603          32.0      NaN
# 27604          41.0      NaN
#
# [27605 rows x 9 columns]

# %% [markdown]
# La columna ``FECHA`` será conservada, las columnas **AAA**, **DD**, y **MM** serán eliminadas, por ser información redundate.

# %%
df_lesiones_victimas.drop(columns=['AAA','MM','DD'],inplace=True)

# %%
resumen_tipos_de_datos(df_lesiones_victimas)
# Out:
#             Columna Tipos de Dato  Cantidad de Nulos  % de Nulos
# 0          ID hecho         [str]                  0        0.00
# 1            FECHA    [Timestamp]                  0        0.00
# 2  VEHICULO_VICTIMA  [float, str]              16272       58.95
# 3              SEXO  [str, float]               2228        8.07
# 4      EDAD_VICTIMA       [float]               4471       16.20
# 5          GRAVEDAD  [float, str]              27068       98.05

# %% [markdown]
# La columna `gravedad` muestra una cantidad alarmante de valores nulos. No obstante, al revisar el diccionario, se aclara que se debe considerar como gravedad `leve`.

# %%
df_lesiones_victimas['GRAVEDAD'] = df_lesiones_victimas['GRAVEDAD'].fillna('leve')

# %% [markdown]
# ### 1. Cambio de tipo de datos

# %% [markdown]
# Conversión columnas ``VEHICULO_VICTIMA``, ``GRAVEDAD`` y ``SEXO`` a tipo categórico

# %%
# Cambio a tipo categórico
df_lesiones_victimas['VEHICULO_VICTIMA'] = df_lesiones_victimas['VEHICULO_VICTIMA'].astype('category')
df_lesiones_victimas['GRAVEDAD'] = df_lesiones_victimas['GRAVEDAD'].astype('category')
df_lesiones_victimas['SEXO'] = df_lesiones_victimas['SEXO'].astype('category')

# %% [markdown]
# Conversión columna `EDAD_VICTIMA` a tipo INT, para facilitar su posterior análisis

# %%
df_lesiones_victimas['EDAD_VICTIMA'] = df_lesiones_victimas['EDAD_VICTIMA'].astype('Int64')

# %%
df_lesiones_victimas.head()
# Out:
#           ID hecho     FECHA  VEHICULO_VICTIMA   SEXO  EDAD_VICTIMA GRAVEDAD
# 0  LC-2019-0000053 2019-01-01              NaN  Varon            57     leve
# 1  LC-2019-0000063 2019-01-01              NaN    NaN          <NA>     leve
# 2  LC-2019-0000079 2019-01-01              NaN  Varon          <NA>     leve
# 3  LC-2019-0000082 2019-01-01              NaN  Varon            45     leve
# 4  LC-2019-0000082 2019-01-01              NaN  Mujer            45     leve

# %% [markdown]
# ### 2. Renombrar Columnas
# Renombrar columnas del DF ``df_lesiones_victimas`` para la concordancia con el DF ``df_lesiones_hechos``

# %%
# Convertimos todo a minúsculas
df_lesiones_victimas.columns = df_lesiones_victimas.columns.str.lower()
df_lesiones_victimas.rename(columns={'id hecho': 'id_hecho', 'fecha ': 'fecha', 'sexo': 'sexo_victima'}, inplace=True)

# %%
df_lesiones_victimas
# Out:
#               id_hecho      fecha    vehiculo_victima sexo_victima  \
# 0      LC-2019-0000053 2019-01-01                 NaN        Varon
# 1      LC-2019-0000063 2019-01-01                 NaN          NaN
# 2      LC-2019-0000079 2019-01-01                 NaN        Varon
# 3      LC-2019-0000082 2019-01-01                 NaN        Varon
# 4      LC-2019-0000082 2019-01-01                 NaN        Mujer
# ...                ...        ...                 ...          ...
# 27600  LC-2021-0451911 2021-09-11  TRANSPORTE PUBLICO        Varon
# 27601  LC-2021-0530228 2021-10-25  TRANSPORTE PUBLICO        Mujer
# 27602  LC-2021-0530228 2021-10-25  TRANSPORTE PUBLICO        Mujer
# 27603  LC-2021-0201378 2021-05-02                MOTO        Varon
# 27604  LC-2021-0229350 2021-05-19                MOTO        Varon
#
#        edad_victima gravedad
# 0                57     leve
# 1              <NA>     leve
# 2              <NA>     leve
# 3                45     leve
# 4                45     leve
# ...             ...      ...
# 27600            87     leve
# 27601            60     leve
# 27602            32     leve
# 27603            32     leve
# 27604            41     leve
#
# [27605 rows x 6 columns]

# %% [markdown]
# ### 3. Renombrar datos de las columnas

# %%
df_lesiones_victimas['sexo_victima'].unique()
# Out:
# ['Varon', NaN, 'Mujer', 'varon', 'mujer', 'MUJER', 'Mujer ']
# Categories (6, object): ['MUJER', 'Mujer', 'Mujer ', 'Varon', 'mujer', 'varon']

# %%
# Mapeo de categorías
mapeo_sexo = {'Varon': 'Masculino', 'varon': 'Masculino', 'Mujer': 'Femenino', 'mujer': 'Femenino', 'MUJER': 'Femenino', 'Mujer ': 'Femenino'}
# Aplicar el mapeo a la columna 'sexo_victima'
df_lesiones_victimas['sexo_victima'] = df_lesiones_victimas['sexo_victima'].map(mapeo_sexo, na_action='ignore')

# %%
df_lesiones_victimas['sexo_victima'].unique()
# Out:
# array(['Masculino', nan, 'Femenino'], dtype=object)

# %% [markdown]
# Corregimos la ortografía de la columna ``vehiculo_victima``

# %%
# Diccionario dado:
diccionario_correcciones = {'movil': 'móvil','camion': 'camión','monopatin': 'monopatín','peaton':'peatón',
                            'transporte publico':'transporte público'}
# Correción acorde al diccionario
df_lesiones_victimas['vehiculo_victima'] = df_lesiones_victimas['vehiculo_victima'].replace(diccionario_correcciones.keys(), diccionario_correcciones.values(), regex=True)

# %%
# Convertimos los valores 'nan' en valores nulos
df_lesiones_victimas.replace('nan', np.nan, inplace=True)

# %%
df_lesiones_victimas.head()
# Out:
#           id_hecho      fecha vehiculo_victima sexo_victima  edad_victima  \
# 0  LC-2019-0000053 2019-01-01              NaN    Masculino            57
# 1  LC-2019-0000063 2019-01-01              NaN          NaN          <NA>
# 2  LC-2019-0000079 2019-01-01              NaN    Masculino          <NA>
# 3  LC-2019-0000082 2019-01-01              NaN    Masculino            45
# 4  LC-2019-0000082 2019-01-01              NaN     Femenino            45
#
#   gravedad
# 0     leve
# 1     leve
# 2     leve
# 3     leve
# 4     leve

# %% [markdown]
# # ETL dataframe ``HOMICIDIOS-HECHOS``

# %%
homicidios_hechos= pd.read_excel('datasets/raw/homicidios.xlsx',sheet_name = 'HECHOS',na_values=['SD', 'sd'])

# %%
homicidios_hechos.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA   HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4.0
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1.0
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7.0
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0.0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5.0
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE             Calle  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  PIEDRA BUENA AV.
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ    PAZ, GRAL. AV.
# 2                         AV ENTRE RIOS 2034       AVENIDA    ENTRE RIOS AV.
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA    LARRAZABAL AV.
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA      SAN JUAN AV.
#
#    Altura                                Cruce  \
# 0     NaN  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1     NaN                  DE LOS CORRALES AV.
# 2  2034.0                                  NaN
# 3     NaN             VILLEGAS, CONRADO, GRAL.
# 4     NaN              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada  COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.       9
# 2                                ENTRE RIOS AV. 2034       1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.       8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO
# 0       MOTO-AUTO    MOTO       AUTO
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       MOTO-AUTO    MOTO       AUTO
# 3         MOTO-SD    MOTO        NaN
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS

# %% [markdown]
# ### 1. Eliminación de columnas
# La columna `FECHA` será conservada, las columnas **AAAA**, **DD**, y **MM**, serán eliminadas por ser consideradas información redundate.

# %%
homicidios_hechos.drop(columns=['AAAA','DD','MM'],inplace=True)

# %% [markdown]
# La columna ``HH``, que representa la hora entera, será conservada, mientras que la columna **HORA**, que incluye los minutos, será eliminada.

# %%
homicidios_hechos.drop(columns=['HORA'],inplace=True)

# %% [markdown]
# Para la ubicación del hecho, se ha decidido utilizar las columnas `pos X` y `pos Y`, procedemos a eliminar las demas columnas que hacen referencia a ubicación.

# %%
homicidios_hechos.drop(columns=['LUGAR_DEL_HECHO','Calle','Altura','Cruce','Dirección Normalizada','XY (CABA)'],inplace=True)

# %% [markdown]
# ### 2. Valores Nulos
# Calcular el porcentaje de valores nulos por columnas

# %%
resumen_tipos_de_datos(homicidios_hechos)
# Out:
#           Columna Tipos de Dato  Cantidad de Nulos  % de Nulos
# 0              ID         [str]                  0        0.00
# 1      N_VICTIMAS         [int]                  0        0.00
# 2           FECHA   [Timestamp]                  0        0.00
# 3              HH       [float]                  1        0.14
# 4   TIPO_DE_CALLE         [str]                  0        0.00
# 5          COMUNA         [int]                  0        0.00
# 6           pos x         [str]                  0        0.00
# 7           pos y         [str]                  0        0.00
# 8   PARTICIPANTES         [str]                  0        0.00
# 9         VICTIMA  [str, float]                  9        1.29
# 10        ACUSADO  [str, float]                 23        3.30

# %% [markdown]
# El porcentaje de valores nulos en el conjunto de datos es bajo, afectando solo a 3 columnas. Sin embargo, se identificaron irregularidades en la columna de "Comuna", donde la presencia de "Comuna 0" indica una inconsistencia, ya que las comunas deben estar en el rango de 1 a 15. Estos casos también serán tratados como valores nulos. Además, se observaron puntos en las columnas "Pos X" y "Pos Y", y se decidirá reemplazarlos por valores nulos para mantener la consistencia en la representación de coordenadas geográficas.

# %%
# Reemplazo de la Comuna 0 por Valores Nulos
homicidios_hechos.loc[homicidios_hechos['COMUNA'] == 0, 'COMUNA'] = np.nan

# Reemplazo de los '.' por valores nulos de las columnas pos x y pos y
homicidios_hechos.loc[homicidios_hechos['pos x'] == '.' ,'pos x'] = np.nan
homicidios_hechos.loc[homicidios_hechos['pos y'] == '.' ,'pos y'] = np.nan

# %%
resumen_tipos_de_datos(homicidios_hechos)
# Out:
#           Columna Tipos de Dato  Cantidad de Nulos  % de Nulos
# 0              ID         [str]                  0        0.00
# 1      N_VICTIMAS         [int]                  0        0.00
# 2           FECHA   [Timestamp]                  0        0.00
# 3              HH       [float]                  1        0.14
# 4   TIPO_DE_CALLE         [str]                  0        0.00
# 5          COMUNA       [float]                  2        0.29
# 6           pos x  [str, float]                 12        1.72
# 7           pos y  [str, float]                 12        1.72
# 8   PARTICIPANTES         [str]                  0        0.00
# 9         VICTIMA  [str, float]                  9        1.29
# 10        ACUSADO  [str, float]                 23        3.30

# %% [markdown]
# ### 3. Cambio de tipo de datos
# Las columnas ``HH``, ``TIPO_DE_CALLE``, ``COMUNA`` y ``ACUSADO`` las pasaremos a tipo **CATEGORY**

# %%
homicidios_hechos['HH'] = homicidios_hechos['HH'].astype('category')
homicidios_hechos['TIPO_DE_CALLE'] = homicidios_hechos['TIPO_DE_CALLE'].astype('category')
homicidios_hechos['COMUNA'] = homicidios_hechos['COMUNA'].astype('category')
homicidios_hechos['ACUSADO'] = homicidios_hechos['ACUSADO'].astype('category')

# %% [markdown]
# Las columnas 'pos X' y 'pos Y' serán transformadas al tipo **FLOAT**

# %%
homicidios_hechos['pos x'] = homicidios_hechos['pos x'].astype('float')
homicidios_hechos['pos y'] = homicidios_hechos['pos y'].astype('float')

# %% [markdown]
# ### 4. Renombrar columnas

# %%
# Pasamos a minúscilas todos los encabezados
homicidios_hechos.columns = homicidios_hechos.columns.str.lower()

# %% [markdown]
# Renombrar columnas: ``id``, ``pos x`` y ``pos y``

# %%
homicidios_hechos.rename(columns={'id': 'id_hecho', 'pos x': 'longitud', 'pos y': 'latitud','tipo_de_calle':'tipo_calle'}, inplace=True)

# %% [markdown]
# Pasar a minúsculas el contenido de las columnas `tipo_calle`, `participantes`, `victima` y `acusado`

# %%
columnas_a_minusc = ['tipo_calle', 'participantes', 'victima', 'acusado']
homicidios_hechos[columnas_a_minusc] = homicidios_hechos[columnas_a_minusc].apply(lambda x: x.astype(str).str.lower())

# %%
homicidios_hechos.head()
# Out:
#     id_hecho  n_victimas      fecha   hh tipo_calle comuna   longitud  \
# 0  2016-0001           1 2016-01-01  4.0    avenida    8.0 -58.475340
# 1  2016-0002           1 2016-01-02  1.0   gral paz    9.0 -58.508775
# 2  2016-0003           1 2016-01-03  7.0    avenida    1.0 -58.390403
# 3  2016-0004           1 2016-01-10  0.0    avenida    8.0 -58.465039
# 4  2016-0005           1 2016-01-21  5.0    avenida    1.0 -58.387183
#
#      latitud   participantes victima    acusado
# 0 -34.687570       moto-auto    moto       auto
# 1 -34.669777  auto-pasajeros    auto  pasajeros
# 2 -34.631894       moto-auto    moto       auto
# 3 -34.680930         moto-sd    moto        nan
# 4 -34.622466  moto-pasajeros    moto  pasajeros

# %%
# Convertimos los nan a valores nulos
homicidios_hechos.replace('nan', np.nan, inplace=True)

# %% [markdown]
# Creamos la columna 'gravedad' y asignamos el valor 'fatal'

# %%
homicidios_hechos['gravedad']='fatal'

# %%
homicidios_hechos.head()
# Out:
#     id_hecho  n_victimas      fecha   hh tipo_calle comuna   longitud  \
# 0  2016-0001           1 2016-01-01  4.0    avenida    8.0 -58.475340
# 1  2016-0002           1 2016-01-02  1.0   gral paz    9.0 -58.508775
# 2  2016-0003           1 2016-01-03  7.0    avenida    1.0 -58.390403
# 3  2016-0004           1 2016-01-10  0.0    avenida    8.0 -58.465039
# 4  2016-0005           1 2016-01-21  5.0    avenida    1.0 -58.387183
#
#      latitud   participantes victima    acusado gravedad
# 0 -34.687570       moto-auto    moto       auto    fatal
# 1 -34.669777  auto-pasajeros    auto  pasajeros    fatal
# 2 -34.631894       moto-auto    moto       auto    fatal
# 3 -34.680930         moto-sd    moto        NaN    fatal
# 4 -34.622466  moto-pasajeros    moto  pasajeros    fatal

# %% [markdown]
# Cambiar el contenido de la columna **victima**, según el diccionario dado.

# %%
mapeo_correcciones_victima = {'peaton': 'peatón','movil': 'móvil'}
homicidios_hechos['victima'] = homicidios_hechos['victima'].replace(mapeo_correcciones_victima)

# %%
homicidios_hechos.head()
# Out:
#     id_hecho  n_victimas      fecha   hh tipo_calle comuna   longitud  \
# 0  2016-0001           1 2016-01-01  4.0    avenida    8.0 -58.475340
# 1  2016-0002           1 2016-01-02  1.0   gral paz    9.0 -58.508775
# 2  2016-0003           1 2016-01-03  7.0    avenida    1.0 -58.390403
# 3  2016-0004           1 2016-01-10  0.0    avenida    8.0 -58.465039
# 4  2016-0005           1 2016-01-21  5.0    avenida    1.0 -58.387183
#
#      latitud   participantes victima    acusado gravedad
# 0 -34.687570       moto-auto    moto       auto    fatal
# 1 -34.669777  auto-pasajeros    auto  pasajeros    fatal
# 2 -34.631894       moto-auto    moto       auto    fatal
# 3 -34.680930         moto-sd    moto        NaN    fatal
# 4 -34.622466  moto-pasajeros    moto  pasajeros    fatal

# %%
resumen_tipos_de_datos(homicidios_hechos)
# Out:
#           Columna Tipos de Dato  Cantidad de Nulos  % de Nulos
# 0        id_hecho         [str]                  0        0.00
# 1      n_victimas         [int]                  0        0.00
# 2           fecha   [Timestamp]                  0        0.00
# 3              hh  [float, nan]                  1        0.14
# 4      tipo_calle         [str]                  0        0.00
# 5          comuna  [float, nan]                  2        0.29
# 6        longitud       [float]                 12        1.72
# 7         latitud       [float]                 12        1.72
# 8   participantes         [str]                  0        0.00
# 9         victima  [str, float]                  9        1.29
# 10        acusado  [str, float]                 23        3.30
# 11       gravedad         [str]                  0        0.00

# %% [markdown]
# # ETL dataframe ``HOMICIDIOS-VICTIMAS``

# %%
df_homicidios_victimas= pd.read_excel('datasets/raw/homicidios.xlsx',sheet_name = 'VICTIMAS',na_values=['SD', 'sd'])

# %%
df_homicidios_victimas.head()
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO  EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO  19.0
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO  70.0
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO  30.0
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO  18.0
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO  29.0
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3                  NaN
# 4  2016-02-01 00:00:00

# %% [markdown]
# ### 1. Eliminación de columnas
# La columna `FECHA` será conservada, las columnas **AAAA**, **DD**, y **MM**, serán eliminadas por ser consideradas información redundate.

# %%
df_homicidios_victimas.drop(columns=['AAAA','MM','DD','FECHA_FALLECIMIENTO'],inplace=True)

# %% [markdown]
# ### 2. Valores nulos

# %%
resumen_tipos_de_datos(df_homicidios_victimas)
# Out:
#     Columna Tipos de Dato  Cantidad de Nulos  % de Nulos
# 0  ID_hecho         [str]                  0        0.00
# 1     FECHA   [Timestamp]                  0        0.00
# 2       ROL  [str, float]                 11        1.53
# 3   VICTIMA  [str, float]                  9        1.26
# 4      SEXO  [str, float]                  6        0.84
# 5      EDAD       [float]                 53        7.39

# %% [markdown]
# ### 3. Cambio de tipo de datos
# Conversión de columnas ``ROL``, ``VICTIMA`` y ``SEXO`` a tipo categórico

# %%
df_homicidios_victimas['ROL'] = df_homicidios_victimas['ROL'].astype('category')
df_homicidios_victimas['VICTIMA'] = df_homicidios_victimas['VICTIMA'].astype('category')
df_homicidios_victimas['SEXO'] = df_homicidios_victimas['SEXO'].astype('category')

# %% [markdown]
# ### 4. Renombrar columnas
# Todos los nombres de las columnas serán convertidos a minúsculas.

# %%
df_homicidios_victimas.columns = df_homicidios_victimas.columns.str.lower()

# %% [markdown]
# Cambiamos el nombre de las columnas

# %%
df_homicidios_victimas.rename(columns={'edad': 'edad_victima','victima':'vehiculo_victima','sexo':'sexo_victima'}, inplace=True)

# %% [markdown]
# A las columnas 'rol', 'victima', 'sexo' y 'acusado' se les cambió el contenido de sus filas a minúsculas.

# %%
columnas_a_minusc = ['rol', 'vehiculo_victima', 'sexo_victima']
df_homicidios_victimas[columnas_a_minusc] = df_homicidios_victimas[columnas_a_minusc].apply(lambda x: x.astype(str).str.lower())

# %%
df_homicidios_victimas
# Out:
#       id_hecho      fecha                   rol vehiculo_victima sexo_victima  \
# 0    2016-0001 2016-01-01             conductor             moto    masculino
# 1    2016-0002 2016-01-02             conductor             auto    masculino
# 2    2016-0003 2016-01-03             conductor             moto    masculino
# 3    2016-0004 2016-01-10             conductor             moto    masculino
# 4    2016-0005 2016-01-21             conductor             moto    masculino
# ..         ...        ...                   ...              ...          ...
# 712  2021-0092 2021-12-12                peaton           peaton     femenino
# 713  2021-0093 2021-12-13  pasajero_acompañante             moto     femenino
# 714  2021-0094 2021-12-20  pasajero_acompañante             moto     femenino
# 715  2021-0095 2021-12-30             conductor             moto    masculino
# 716  2021-0096 2021-12-15             conductor             auto    masculino
#
#      edad_victima
# 0            19.0
# 1            70.0
# 2            30.0
# 3            18.0
# 4            29.0
# ..            ...
# 712          50.0
# 713          18.0
# 714          43.0
# 715          27.0
# 716          60.0
#
# [717 rows x 6 columns]

# %%
df_homicidios_victimas['rol'].unique()
# Out:
# array(['conductor', 'pasajero_acompañante', 'peaton', 'nan', 'ciclista'],
#       dtype=object)

# %%
df_homicidios_victimas['vehiculo_victima'].unique()
# Out:
# array(['moto', 'auto', 'peaton', 'nan', 'cargas', 'bicicleta',
#        'pasajeros', 'movil'], dtype=object)

# %% [markdown]
# Cambiamos los datos de las columnas ``rol`` y ``vehiculo_victima``, siguiendo las indicaciones del diccionario

# %%
# Diccionario de correcciones
diccionario_correcciones_rol = {'pasajero_acompañante': 'pasajero', 'peaton': 'peatón'}
diccionario_correcciones_vehi_vic = {'peaton': 'peatón', 'movil': 'móvil'}
df_homicidios_victimas['rol'] = df_homicidios_victimas['rol'].replace(diccionario_correcciones_rol)
df_homicidios_victimas['vehiculo_victima'] = df_homicidios_victimas['vehiculo_victima'].replace(diccionario_correcciones_vehi_vic)

# %%
df_homicidios_victimas['gravedad'] = 'fatal'

# %%
df_homicidios_victimas.head()
# Out:
#     id_hecho      fecha        rol vehiculo_victima sexo_victima  \
# 0  2016-0001 2016-01-01  conductor             moto    masculino
# 1  2016-0002 2016-01-02  conductor             auto    masculino
# 2  2016-0003 2016-01-03  conductor             moto    masculino
# 3  2016-0004 2016-01-10  conductor             moto    masculino
# 4  2016-0005 2016-01-21  conductor             moto    masculino
#
#    edad_victima gravedad
# 0          19.0    fatal
# 1          70.0    fatal
# 2          30.0    fatal
# 3          18.0    fatal
# 4          29.0    fatal

# %% [markdown]
# # CONCATENACIÓN DE LOS DATAFRAMES

# %% [markdown]
# ### DataFrame ``homicidios_hechos`` y ``homicidios_víctimas``

# %% [markdown]
# Integración de Datos: Fusión de Información sobre Homicidios Hechos y Víctimas

# %%
df_homicidios_combinado = pd.merge(homicidios_hechos, df_homicidios_victimas, how='inner', on='id_hecho')

# %%
df_homicidios_combinado
# Out:
#       id_hecho  n_victimas    fecha_x    hh tipo_calle comuna   longitud  \
# 0    2016-0001           1 2016-01-01   4.0    avenida    8.0 -58.475340
# 1    2016-0002           1 2016-01-02   1.0   gral paz    9.0 -58.508775
# 2    2016-0003           1 2016-01-03   7.0    avenida    1.0 -58.390403
# 3    2016-0004           1 2016-01-10   0.0    avenida    8.0 -58.465039
# 4    2016-0005           1 2016-01-21   5.0    avenida    1.0 -58.387183
# ..         ...         ...        ...   ...        ...    ...        ...
# 712  2021-0093           1 2021-12-13  17.0    avenida    7.0 -58.433538
# 713  2021-0094           1 2021-12-20   1.0  autopista    9.0 -58.467398
# 714  2021-0095           1 2021-12-30   0.0    avenida   11.0 -58.472934
# 715  2021-0096           1 2021-12-15  10.0    avenida    9.0 -58.470668
# 716  2021-0097           1 2021-11-18   6.0      calle    1.0 -58.379762
#
#        latitud   participantes    victima    acusado gravedad_x    fecha_y  \
# 0   -34.687570       moto-auto       moto       auto      fatal 2016-01-01
# 1   -34.669777  auto-pasajeros       auto  pasajeros      fatal 2016-01-02
# 2   -34.631894       moto-auto       moto       auto      fatal 2016-01-03
# 3   -34.680930         moto-sd       moto        NaN      fatal 2016-01-10
# 4   -34.622466  moto-pasajeros       moto  pasajeros      fatal 2016-01-21
# ..         ...             ...        ...        ...        ...        ...
# 712 -34.645616       moto-auto       moto       auto      fatal 2021-12-13
# 713 -34.651178       moto-auto       moto       auto      fatal 2021-12-20
# 714 -34.619847     moto-cargas       moto     cargas      fatal 2021-12-30
# 715 -34.650217     auto-cargas       auto     cargas      fatal 2021-12-15
# 716 -34.586796  bicicleta-auto  bicicleta       auto      fatal 2021-11-18
#
#            rol vehiculo_victima sexo_victima  edad_victima gravedad_y
# 0    conductor             moto    masculino          19.0      fatal
# 1    conductor             auto    masculino          70.0      fatal
# 2    conductor             moto    masculino          30.0      fatal
# 3    conductor             moto    masculino          18.0      fatal
# 4    conductor             moto    masculino          29.0      fatal
# ..         ...              ...          ...           ...        ...
# 712   pasajero             moto     femenino          18.0      fatal
# 713   pasajero             moto     femenino          43.0      fatal
# 714  conductor             moto    masculino          27.0      fatal
# 715  conductor             auto    masculino          60.0      fatal
# 716   ciclista        bicicleta    masculino          53.0      fatal
#
# [717 rows x 18 columns]

# %% [markdown]
# Refinamiento de Datos: Ajuste de columnas en el conjunto de datos de Homicidios Combinado, según el diccionario dado.

# %%
df_homicidios_combinado.drop(columns=['fecha_y', 'gravedad_y'], inplace=True)
df_homicidios_combinado.rename(columns={
    'fecha_x': 'fecha',
    'gravedad_x': 'gravedad',
    'hh': 'franja_hora',
    'longitud': 'pos_x',
    'latitud': 'pos_y',
    'vehiculo_victima': 'vehiculo_victima',  # Asumiendo que deseas conservar este nombre
    'sexo_victima': 'sexo_victima',
    'edad_victima': 'edad_victima'
    }, inplace=True)

# %%
df_homicidios_combinado
# Out:
#       id_hecho  n_victimas      fecha franja_hora tipo_calle comuna  \
# 0    2016-0001           1 2016-01-01         4.0    avenida    8.0
# 1    2016-0002           1 2016-01-02         1.0   gral paz    9.0
# 2    2016-0003           1 2016-01-03         7.0    avenida    1.0
# 3    2016-0004           1 2016-01-10         0.0    avenida    8.0
# 4    2016-0005           1 2016-01-21         5.0    avenida    1.0
# ..         ...         ...        ...         ...        ...    ...
# 712  2021-0093           1 2021-12-13        17.0    avenida    7.0
# 713  2021-0094           1 2021-12-20         1.0  autopista    9.0
# 714  2021-0095           1 2021-12-30         0.0    avenida   11.0
# 715  2021-0096           1 2021-12-15        10.0    avenida    9.0
# 716  2021-0097           1 2021-11-18         6.0      calle    1.0
#
#          pos_x      pos_y   participantes    victima    acusado gravedad  \
# 0   -58.475340 -34.687570       moto-auto       moto       auto    fatal
# 1   -58.508775 -34.669777  auto-pasajeros       auto  pasajeros    fatal
# 2   -58.390403 -34.631894       moto-auto       moto       auto    fatal
# 3   -58.465039 -34.680930         moto-sd       moto        NaN    fatal
# 4   -58.387183 -34.622466  moto-pasajeros       moto  pasajeros    fatal
# ..         ...        ...             ...        ...        ...      ...
# 712 -58.433538 -34.645616       moto-auto       moto       auto    fatal
# 713 -58.467398 -34.651178       moto-auto       moto       auto    fatal
# 714 -58.472934 -34.619847     moto-cargas       moto     cargas    fatal
# 715 -58.470668 -34.650217     auto-cargas       auto     cargas    fatal
# 716 -58.379762 -34.586796  bicicleta-auto  bicicleta       auto    fatal
#
#            rol vehiculo_victima sexo_victima  edad_victima
# 0    conductor             moto    masculino          19.0
# 1    conductor             auto    masculino          70.0
# 2    conductor             moto    masculino          30.0
# 3    conductor             moto    masculino          18.0
# 4    conductor             moto    masculino          29.0
# ..         ...              ...          ...           ...
# 712   pasajero             moto     femenino          18.0
# 713   pasajero             moto     femenino          43.0
# 714  conductor             moto    masculino          27.0
# 715  conductor             auto    masculino          60.0
# 716   ciclista        bicicleta    masculino          53.0
#
# [717 rows x 16 columns]

# %%
df_homicidios_combinado.to_csv('datasets/homicidios_hechos_victimas.csv', index=False)

# %% [markdown]
# ### DataFrame ``lesiones_hechos`` y ``lesiones_víctimas``

# %% [markdown]
# Integración de Datos: Fusión de Información sobre Homicidios Hechos y Víctimas

# %%
df_final_lesiones = pd.merge(df_lesiones_hechos, df_lesiones_victimas, on='id_hecho', how='inner')

# %%
df_final_lesiones
# Out:
#               id_hecho  n_victimas    fecha_x  hh  comuna tipo_calle  \
# 0      LC-2019-0000179           1 2019-01-01   9      14        NaN
# 1      LC-2019-0000053           1 2019-01-01   1       8        NaN
# 2      LC-2019-0000063           1 2019-01-01   2       8        NaN
# 3      LC-2019-0000079           1 2019-01-01   2       7        NaN
# 4      LC-2019-0000082           4 2019-01-01   4       3        NaN
# ...                ...         ...        ...  ..     ...        ...
# 27593  LC-2021-0652865           2 2021-12-31  19       9    avenida
# 27594  LC-2021-0652865           2 2021-12-31  19       9    avenida
# 27595  LC-2021-0652907           1 2021-12-31  20       1        NaN
# 27596  LC-2021-0652921           1 2021-12-31  22       5      calle
# 27597  LC-2020-0244615           1 2020-05-17  21    <NA>        NaN
#
#            longitud       latitud   victima             acusado  \
# 0     -5.840891e+01 -3.455966e+01  ciclista                 NaN
# 1     -5.844351e+01 -3.466913e+01      auto                 NaN
# 2     -5.846834e+01 -3.467756e+01       NaN                 NaN
# 3     -5.843742e+01 -3.464735e+01    peatón                 NaN
# 4     -5.839822e+01 -3.460458e+01      auto                 NaN
# ...             ...           ...       ...                 ...
# 27593 -5.848833e+01 -3.464175e+01       NaN                 NaN
# 27594 -5.848833e+01 -3.464175e+01       NaN                 NaN
# 27595 -5.838289e+01 -3.458308e+01       NaN                 NaN
# 27596 -5.841453e+01 -3.461429e+01      moto  transporte publico
# 27597 -5.829963e+09 -3.472891e+09      moto                auto
#
#                  participantes gravedad_x    fecha_y vehiculo_victima  \
# 0                  ciclista-sd       leve 2019-01-01              NaN
# 1                      auto-sd       leve 2019-01-01              NaN
# 2                        sd-sd       leve 2019-01-01              NaN
# 3                    peaton-sd       leve 2019-01-01              NaN
# 4                      auto-sd       leve 2019-01-01              NaN
# ...                        ...        ...        ...              ...
# 27593                    sd-sd       leve 2021-12-31              NaN
# 27594                    sd-sd       leve 2021-12-31              NaN
# 27595                    sd-sd       leve 2021-12-31              NaN
# 27596  moto-transporte publico      grave 2021-12-31             MOTO
# 27597                moto-auto       leve 2020-05-17             MOTO
#
#       sexo_victima  edad_victima gravedad_y
# 0              NaN          <NA>       leve
# 1        Masculino            57       leve
# 2              NaN          <NA>       leve
# 3        Masculino          <NA>       leve
# 4        Masculino            45       leve
# ...            ...           ...        ...
# 27593    Masculino            28       leve
# 27594    Masculino            52       leve
# 27595    Masculino            23       leve
# 27596    Masculino            31      GRAVE
# 27597    Masculino            46       leve
#
# [27598 rows x 17 columns]

# %%
# Eliminar columnas redundantes
df_final_lesiones = df_final_lesiones.drop(columns=['fecha_y', 'gravedad_y'])

# Renombrar columnas
df_final_lesiones.rename(columns={
    'fecha_x': 'fecha',
    'hh': 'franja_hora',
    'gravedad_x': 'gravedad',
    'longitud': 'pos_x',
    'latitud': 'pos_y',
}, inplace=True)

# %%
df_final_lesiones
# Out:
#               id_hecho  n_victimas      fecha  franja_hora  comuna tipo_calle  \
# 0      LC-2019-0000179           1 2019-01-01            9      14        NaN
# 1      LC-2019-0000053           1 2019-01-01            1       8        NaN
# 2      LC-2019-0000063           1 2019-01-01            2       8        NaN
# 3      LC-2019-0000079           1 2019-01-01            2       7        NaN
# 4      LC-2019-0000082           4 2019-01-01            4       3        NaN
# ...                ...         ...        ...          ...     ...        ...
# 27593  LC-2021-0652865           2 2021-12-31           19       9    avenida
# 27594  LC-2021-0652865           2 2021-12-31           19       9    avenida
# 27595  LC-2021-0652907           1 2021-12-31           20       1        NaN
# 27596  LC-2021-0652921           1 2021-12-31           22       5      calle
# 27597  LC-2020-0244615           1 2020-05-17           21    <NA>        NaN
#
#               pos_x         pos_y   victima             acusado  \
# 0     -5.840891e+01 -3.455966e+01  ciclista                 NaN
# 1     -5.844351e+01 -3.466913e+01      auto                 NaN
# 2     -5.846834e+01 -3.467756e+01       NaN                 NaN
# 3     -5.843742e+01 -3.464735e+01    peatón                 NaN
# 4     -5.839822e+01 -3.460458e+01      auto                 NaN
# ...             ...           ...       ...                 ...
# 27593 -5.848833e+01 -3.464175e+01       NaN                 NaN
# 27594 -5.848833e+01 -3.464175e+01       NaN                 NaN
# 27595 -5.838289e+01 -3.458308e+01       NaN                 NaN
# 27596 -5.841453e+01 -3.461429e+01      moto  transporte publico
# 27597 -5.829963e+09 -3.472891e+09      moto                auto
#
#                  participantes gravedad vehiculo_victima sexo_victima  \
# 0                  ciclista-sd     leve              NaN          NaN
# 1                      auto-sd     leve              NaN    Masculino
# 2                        sd-sd     leve              NaN          NaN
# 3                    peaton-sd     leve              NaN    Masculino
# 4                      auto-sd     leve              NaN    Masculino
# ...                        ...      ...              ...          ...
# 27593                    sd-sd     leve              NaN    Masculino
# 27594                    sd-sd     leve              NaN    Masculino
# 27595                    sd-sd     leve              NaN    Masculino
# 27596  moto-transporte publico    grave             MOTO    Masculino
# 27597                moto-auto     leve             MOTO    Masculino
#
#        edad_victima
# 0              <NA>
# 1                57
# 2              <NA>
# 3              <NA>
# 4                45
# ...             ...
# 27593            28
# 27594            52
# 27595            23
# 27596            31
# 27597            46
#
# [27598 rows x 15 columns]

# %%
resumen_tipos_de_datos(df_final_lesiones)
# Out:
#              Columna Tipos de Dato  Cantidad de Nulos  % de Nulos
# 0           id_hecho         [str]                  0        0.00
# 1         n_victimas         [int]                  0        0.00
# 2              fecha   [Timestamp]                  0        0.00
# 3        franja_hora       [float]                  8        0.03
# 4             comuna       [float]               1624        5.88
# 5         tipo_calle  [float, str]              12879       46.67
# 6              pos_x       [float]               1656        6.00
# 7              pos_y       [float]               1656        6.00
# 8            victima  [str, float]              12822       46.46
# 9            acusado  [float, str]              17918       64.92
# 10     participantes         [str]                  0        0.00
# 11          gravedad         [str]                  0        0.00
# 12  vehiculo_victima    [nan, str]              16269       58.95
# 13      sexo_victima  [float, str]               2228        8.07
# 14      edad_victima       [float]               4471       16.20

# %% [markdown]
# ## Guardar la data procesada en formato CSV

# %%
df_final_lesiones.to_csv('datasets/lesiones_hechos_victimas.csv', index=False)
